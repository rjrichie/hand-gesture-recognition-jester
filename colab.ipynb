# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/hand-gesture-recognition
# Out:
# /content/drive/MyDrive/hand-gesture-recognition

# %%
# %pwd
# Out:
# '/content/hand-gesture-recognition-jester'

# %% [markdown]
# # Unzip

# %%
# !cp /content/drive/MyDrive/hand-gesture-recognition-jester.tar /content/

# %%
# !tar -xvf /content/hand-gesture-recognition-jester.tar
# Out:
# Streaming output truncated to the last 5000 lines.
# hand-gesture-recognition-jester/dataset/modified/data/98990/._00027.jpg
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.provenance'
# hand-gesture-recognition-jester/dataset/modified/data/98990/00027.jpg
# hand-gesture-recognition-jester/dataset/modified/data/98990/._00033.jpg
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.provenance'
# hand-gesture-recognition-jester/dataset/modified/data/98990/00033.jpg
# hand-gesture-recognition-jester/dataset/modified/data/98990/._00037.jpg
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.provenance'
# ...

# %% [markdown]
# # Setup

# %%
# %cd /content/hand-gesture-recognition-jester/
# Out:
# /content/hand-gesture-recognition-jester

# %%
# %ls -alih
# Out:
# total 248K
# 3412685 drwxr-xr-x 7  501 staff 4.0K Nov  3 02:44 ./
# 5767181 drwxr-xr-x 1 root root  4.0K Nov  3 14:43 ../
# 3412694 -rwxr-xr-x 1  501 staff  163 Nov  3 02:44 ._checkpoints*
# 3412695 drwxr-xr-x 2  501 staff 4.0K Nov  3 02:44 checkpoints/
# 3412690 -rwxr-xr-x 1  501 staff  163 Nov  3 02:25 ._dataset*
# 3412691 drwxr-xr-x 4  501 staff 4.0K Nov  3 14:43 dataset/
# 3412686 -rw-r--r-- 1  501 staff  120 Nov  3 02:47 ._.DS_Store
# 3412687 -rw-r--r-- 1  501 staff 6.1K Nov  3 02:47 .DS_Store
# 3412704 -rwxr-xr-x 1  501 staff  163 Nov  3 02:27 ._.git*
# 3412705 drwxr-xr-x 7  501 staff 4.0K Nov  3 14:43 .git/
# 3412698 -rw-r--r-- 1  501 staff  163 Nov  3 02:24 ._.gitignore
# 3412699 -rw-r--r-- 1  501 staff 4.7K Nov  3 02:24 .gitignore
# 3412692 -rw-r--r-- 1  501 staff  163 Nov  3 02:34 ._pyproject.toml
# 3412693 -rw-r--r-- 1  501 staff  308 Nov  3 02:34 pyproject.toml
# 3412702 -rw-r--r-- 1  501 staff  163 Nov  3 02:34 ._.python-version
# ...

# %%
# %rm -rf .venv/

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 95.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 100.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 155.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 125.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 88.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 158.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 121.1 MB/s eta 0:00:00
# ...

# %%
# !python src/train.py
# Out:
# Epoch [1/20] Train Loss: 1.7775, Train Acc: 0.3341 | Val Loss: 1.4197, Val Acc: 0.4704
# Checkpoint saved to checkpoints/c3d_epoch1.pth
#
# Epoch [2/20] Train Loss: 1.2897, Train Acc: 0.5008 | Val Loss: 1.2743, Val Acc: 0.5667
# Checkpoint saved to checkpoints/c3d_epoch2.pth
#
# Epoch [3/20] Train Loss: 1.1089, Train Acc: 0.5707 | Val Loss: 0.8982, Val Acc: 0.6667
# Checkpoint saved to checkpoints/c3d_epoch3.pth
#
# Epoch [4/20] Train Loss: 0.9236, Train Acc: 0.6493 | Val Loss: 0.6569, Val Acc: 0.7741
# Checkpoint saved to checkpoints/c3d_epoch4.pth
#
# Epoch [5/20] Train Loss: 0.7790, Train Acc: 0.7031 | Val Loss: 0.5821, Val Acc: 0.7852
# Checkpoint saved to checkpoints/c3d_epoch5.pth
#
# Epoch [6/20] Train Loss: 0.6828, Train Acc: 0.7409 | Val Loss: 0.5791, Val Acc: 0.7778
# Checkpoint saved to checkpoints/c3d_epoch6.pth
#
# Epoch [7/20] Train Loss: 0.6051, Train Acc: 0.7774 | Val Loss: 0.4747, Val Acc: 0.8185
# Checkpoint saved to checkpoints/c3d_epoch7.pth
#
# ...

# %% [markdown]
# # Save Model Checkpoint back to GDrive

# %%
# !ls
# Out:
# checkpoints  dataset  pyproject.toml  README.md  src  uv.lock

# %%
# !python src/train.py
# Out:
# Resumed from checkpoint: checkpoints/c3d_epoch8.pth (starting epoch 9)
# Epoch [9/20] Train Loss: 0.4725, Train Acc: 0.8292 | Val Loss: 0.4379, Val Acc: 0.8259
# Checkpoint saved to checkpoints/c3d_epoch9.pth
#
# Epoch [10/20] Train Loss: 0.4283, Train Acc: 0.8484 | Val Loss: 0.3846, Val Acc: 0.8593
# Checkpoint saved to checkpoints/c3d_epoch10.pth
#
# Epoch [11/20] Train Loss: 0.3882, Train Acc: 0.8672 | Val Loss: 0.4843, Val Acc: 0.8519
# Checkpoint saved to checkpoints/c3d_epoch11.pth
#
# Epoch [12/20] Train Loss: 0.3449, Train Acc: 0.8790 | Val Loss: 0.3880, Val Acc: 0.8667
# Checkpoint saved to checkpoints/c3d_epoch12.pth
#
# Epoch [13/20] Train Loss: 0.3330, Train Acc: 0.8848 | Val Loss: 0.4402, Val Acc: 0.8630
# Checkpoint saved to checkpoints/c3d_epoch13.pth
#
# Epoch [14/20] Train Loss: 0.2934, Train Acc: 0.8974 | Val Loss: 0.3813, Val Acc: 0.8852
# Checkpoint saved to checkpoints/c3d_epoch14.pth
#
# ...

# %%
# !cp checkpoints/c3d_epoch20.pth /content/drive/MyDrive/hand-gesture-recognition

# %%
# !cp checkpoints/c3d_epoch12.pth /content/drive/MyDrive/hand-gesture-recognition/checkpoints

# %%
# !python src/evaluate.py
# Out:
# Validation Loss: 0.4777
# Validation Accuracy: 87.04%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.735     0.833     0.781        30
#            1      0.958     0.767     0.852        30
#            2      0.833     0.833     0.833        30
#            3      0.806     0.967     0.879        30
#            4      0.968     1.000     0.984        30
#            5      0.800     0.933     0.862        30
#            6      0.966     0.933     0.949        30
#            7      0.960     0.800     0.873        30
#            8      0.885     0.767     0.821        30
#
#     accuracy                          0.870       270
#    macro avg      0.879     0.870     0.870       270
# weighted avg      0.879     0.870     0.870       270
#
# Confusion Matrix:
# [[25  0  0  3  0  1  0  0  1]
#  [ 0 23  5  0  0  2  0  0  0]
#  [ 2  1 25  0  0  2  0  0  0]
#  [ 0  0  0 29  1  0  0  0  0]
#  [ 0  0  0  0 30  0  0  0  0]
# ...

# %%
# !python src/evaluate_pretty.py
# Out:
# 🔧 Loading model and checkpoint...
# ✅ Model loaded successfully.
#
# 🚀 Evaluating model...
# 📊 Evaluation Results
# ...
# Validation Loss     : 0.3784
# Validation Accuracy : 88.89%
# ...
#
# 🧠 Classification Report:
#               precision    recall  f1-score   support
#
#            7      0.794     0.900     0.844        30
#            8      0.900     0.900     0.900        30
#            9      0.931     0.900     0.915        30
#           10      0.906     0.967     0.935        30
#           17      0.909     1.000     0.952        30
#           20      0.964     0.900     0.931        30
#           24      0.931     0.900     0.915        30
#           26      0.839     0.867     0.852        30
#           27      0.833     0.667     0.741        30
#
#     accuracy                          0.889       270
#    macro avg      0.890     0.889     0.887       270
# weighted avg      0.890     0.889     0.887       270
#
#
# ...

# %%
# %run src/evaluate_pretty.py
# Out:
# 🔧 Loading model and checkpoint...
# ✅ Model loaded successfully.
#
# 🚀 Evaluating model...
# 📊 Evaluation Results
# ...
# Validation Loss     : 0.4777
# Validation Accuracy : 87.04%
# ...
#
# 🧠 Classification Report:
#               precision    recall  f1-score   support
#
#            7      0.735     0.833     0.781        30
#            8      0.958     0.767     0.852        30
#            9      0.833     0.833     0.833        30
#           10      0.806     0.967     0.879        30
#           17      0.968     1.000     0.984        30
#           20      0.800     0.933     0.862        30
#           24      0.966     0.933     0.949        30
#           26      0.960     0.800     0.873        30
#           27      0.885     0.767     0.821        30
#
#     accuracy                          0.870       270
#    macro avg      0.879     0.870     0.870       270
# weighted avg      0.879     0.870     0.870       270

# %%
# !python src/evaluate_range.py
# Out:
# 🔧 Loading model from epoch 15...
# ✅ Epoch 15 — Loss: 0.3791, Accuracy: 86.30%
# 🖼️ Saved: results/confusion_matrix_epoch15.png
# 📄 Saved: results/classification_report_epoch15.csv
# 🧾 Saved: results/summary_metrics_epoch15.txt
#
# 🔧 Loading model from epoch 16...
# ✅ Epoch 16 — Loss: 0.4777, Accuracy: 87.04%
# 🖼️ Saved: results/confusion_matrix_epoch16.png
# 📄 Saved: results/classification_report_epoch16.csv
# 🧾 Saved: results/summary_metrics_epoch16.txt
#
# 🔧 Loading model from epoch 17...
# ✅ Epoch 17 — Loss: 0.3784, Accuracy: 88.89%
# 🖼️ Saved: results/confusion_matrix_epoch17.png
# 📄 Saved: results/classification_report_epoch17.csv
# 🧾 Saved: results/summary_metrics_epoch17.txt
#
# 🔧 Loading model from epoch 18...
# ✅ Epoch 18 — Loss: 0.3790, Accuracy: 88.89%
# 🖼️ Saved: results/confusion_matrix_epoch18.png
# 📄 Saved: results/classification_report_epoch18.csv
# 🧾 Saved: results/summary_metrics_epoch18.txt
#
# 🔧 Loading model from epoch 19...
# ...

# %%
# !python src/plot_training_curves.py
# Out:
# ✅ Saved extracted metrics to results/training_metrics.csv
# 📉 Saved results/loss_curve.png
# 📈 Saved results/accuracy_curve.png

# %%
# !rm -rf /content/drive/MyDrive/hand-gesture-recognition/results/

# %%
# !tar -cvf results.tar /content/hand-gesture-recognition-jester/results/
# Out:
# tar: Removing leading `/' from member names
# /content/hand-gesture-recognition-jester/results/
# /content/hand-gesture-recognition-jester/results/classification_report_epoch18.csv
# /content/hand-gesture-recognition-jester/results/summary_metrics_epoch16.txt
# /content/hand-gesture-recognition-jester/results/classification_report_epoch16.csv
# /content/hand-gesture-recognition-jester/results/confusion_matrix_epoch15.png
# /content/hand-gesture-recognition-jester/results/summary_metrics_epoch15.txt
# /content/hand-gesture-recognition-jester/results/confusion_matrix_epoch20.png
# /content/hand-gesture-recognition-jester/results/training_metrics.csv
# /content/hand-gesture-recognition-jester/results/classification_report_epoch17.csv
# /content/hand-gesture-recognition-jester/results/classification_report_epoch20.csv
# /content/hand-gesture-recognition-jester/results/summary_metrics_epoch17.txt
# /content/hand-gesture-recognition-jester/results/loss_curve.png
# ...

# %%
# !cp -r /content/hand-gesture-recognition-jester/results.tar /content/drive/MyDrive/hand-gesture-recognition/
